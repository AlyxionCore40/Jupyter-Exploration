# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyxionCore40/Jupyter-Exploration/blob/main/My_first_Notebook_Alexia_Y_Chavez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"My First mardown cell in Jupyter"
# Out:
# 'My First mardown cell in Jupyter'

# %%
print("Hello, World!")
# Out:
# Hello, World!
